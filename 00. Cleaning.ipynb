# %%
from glob import glob
import shutil

# %%
"""
This notebook is used to remove dropbox conflict files
"""

fps = glob('../2_live_bees/2_card_masks/*Roberta*')
for fp in fps:
    new_fp = fp.split(' ')[0] + '.png'
    print(new_fp)
    shutil.move(fp, new_fp)
# Out:
# ../2_live_bees/2_card_masks/2024_06_27_h01b46.png
# ../2_live_bees/2_card_masks/2024_07_24_h34b45.png
# ../2_live_bees/2_card_masks/2024_07_09_h22b31.png
# ../2_live_bees/2_card_masks/2024_06_27_h01b07.png
# ../2_live_bees/2_card_masks/2024_06_10_h02b12.png
# ../2_live_bees/2_card_masks/2024_06_24_h02b16.png
# ../2_live_bees/2_card_masks/2024_06_14_h03b18.png
# ../2_live_bees/2_card_masks/2024_06_24_h12b38.png
# ../2_live_bees/2_card_masks/2024_07_02_h13b23.png
# ../2_live_bees/2_card_masks/2024_06_28_h05b39.png
# ../2_live_bees/2_card_masks/2024_06_28_h13b36.png
# ../2_live_bees/2_card_masks/2024_07_05_h21b24.png
# ../2_live_bees/2_card_masks/2024_07_17_h31b75.png
# ../2_live_bees/2_card_masks/2024_07_11_h23b07.png
# ../2_live_bees/2_card_masks/2024_06_14_h03b25.png
# ../2_live_bees/2_card_masks/2024_06_24_h02b63.png
# ../2_live_bees/2_card_masks/2024_07_26_h32b20.png
# ../2_live_bees/2_card_masks/2024_06_28_h13b13.png
# ../2_live_bees/2_card_masks/2024_07_10_h24b14.png
# ...
